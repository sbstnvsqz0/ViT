# %% [markdown]
# Se clona repositorio con modelos

# %%
# !git clone https://huggingface.co/sbstnvsqz0/ViT_82_0/
# Out:
# Cloning into 'ViT_82_0'...
# Updating files:  15% (3/20)
# Updating files:  20% (4/20)
# Updating files:  25% (5/20)
# Updating files:  30% (6/20)
# Updating files:  35% (7/20)
# Updating files:  40% (8/20)
# Updating files:  45% (9/20)
# Updating files:  50% (10/20)
# Updating files:  55% (11/20)
# Updating files:  60% (12/20)
# Updating files:  65% (13/20)
# Updating files:  70% (14/20)
# Updating files:  75% (15/20)
# Updating files:  80% (16/20)
# Updating files:  85% (17/20)
# Updating files:  90% (18/20)
# Updating files:  95% (19/20)
# Updating files: 100% (20/20)
# Updating files: 100% (20/20), done.
# Filtering content:  33% (2/6)
# Filtering content:  50% (3/6), 103.01 MiB | 31.50 MiB/s
# Filtering content:  66% (4/6), 103.01 MiB | 31.50 MiB/s
# Filtering content:  83% (5/6), 103.01 MiB | 31.50 MiB/s
# Filtering content:  83% (5/6), 256.52 MiB | 87.13 MiB/s
# Filtering content: 100% (6/6), 256.52 MiB | 87.13 MiB/s
# ...

# %%
import torch
import os

# %%
dir_actual = os.path.dirname(os.path.abspath(os.getcwd()))
os.chdir(dir_actual)

# %%
from predict import predict_img

# %% [markdown]
# # Ejemplo de uso:

# %% [markdown]
# predict_img(path exacto de la imagen,
#             path de directorio del modelo a utilizar)

# %%
predict_img("ImagesEx/Boat_Pose_or_Paripurna_Navasana_/272.jpg",
            "demo/ViT_82_0/82_1")
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
